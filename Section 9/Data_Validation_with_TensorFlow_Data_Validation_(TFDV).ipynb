# %% [markdown]
# ## Stage 1: Install all dependencies and setting up the environment

# %%
# !apt-get install python-dev python-snappy
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python-dev is already the newest version (2.7.15~rc1-1).
# python-snappy is already the newest version (0.5-1.1build2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 20 not upgraded.

# %%
# !pip install tensorflow-data-validation
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow-data-validation in /usr/local/lib/python3.8/dist-packages (1.12.0)
# Requirement already satisfied: six<2,>=1.12 in /usr/local/lib/python3.8/dist-packages (from tensorflow-data-validation) (1.15.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-data-validation) (1.2.0)
# Requirement already satisfied: pyarrow<7,>=6 in /usr/local/lib/python3.8/dist-packages (from tensorflow-data-validation) (6.0.1)
# Requirement already satisfied: tensorflow<3,>=2.11 in /usr/local/lib/python3.8/dist-packages (from tensorflow-data-validation) (2.11.0)
# Requirement already satisfied: tensorflow-metadata<1.13,>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-data-validation) (1.12.0)
# Requirement already satisfied: numpy<2,>=1.16 in /usr/local/lib/python3.8/dist-packages (from tensorflow-data-validation) (1.21.6)
# Requirement already satisfied: absl-py<2.0.0,>=0.9 in /usr/local/lib/python3.8/dist-packages (from tensorflow-data-validation) (1.3.0)
# Requirement already satisfied: protobuf<4,>=3.13 in /usr/local/lib/python3.8/dist-packages (from tensorflow-data-validation) (3.19.6)
# Requirement already satisfied: apache-beam[gcp]<3,>=2.40 in /usr/local/lib/python3.8/dist-packages (from tensorflow-data-validation) (2.43.0)
# Requirement already satisfied: tfx-bsl<1.13,>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-data-validation) (1.12.0)
# Requirement already satisfied: pandas<2,>=1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-data-validation) (1.3.5)
# Requirement already satisfied: pyfarmhash<0.4,>=0.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow-data-validation) (0.3.2)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (1.3.0)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (2.7.0)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (2.28.1)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (0.18)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (1.7)
# Requirement already satisfied: orjson<4.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (3.8.3)
# Requirement already satisfied: regex>=2020.6.8 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (2022.6.2)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (1.22.1)
# Requirement already satisfied: objsize<0.6.0,>=0.5.2 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (0.5.2)
# Requirement already satisfied: httplib2<0.21.0,>=0.8 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (0.17.4)
# Requirement already satisfied: cloudpickle~=2.2.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (2.2.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (4.4.0)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (0.3.1.1)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (2.8.2)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (0.19.0)
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (1.51.1)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (1.7.0)
# Requirement already satisfied: pymongo<4.0.0,>=3.8.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (3.13.0)
# Requirement already satisfied: pytz>=2018.3 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (2022.6)
# Requirement already satisfied: google-auth<3,>=1.18.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (2.15.0)
# Requirement already satisfied: google-cloud-vision<2,>=0.38.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (1.0.2)
# Requirement already satisfied: google-apitools<0.5.32,>=0.5.31 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (0.5.31)
# Requirement already satisfied: google-cloud-core<3,>=0.28.1 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (2.3.2)
# Requirement already satisfied: google-cloud-dlp<4,>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (3.9.2)
# Requirement already satisfied: cachetools<5,>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (4.2.4)
# Requirement already satisfied: google-cloud-bigtable<2,>=0.31.1 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (1.7.3)
# Requirement already satisfied: google-cloud-videointelligence<2,>=1.8.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (1.16.3)
# Requirement already satisfied: google-cloud-language<2,>=1.3.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (1.3.2)
# Requirement already satisfied: google-cloud-bigquery-storage<2.14,>=2.6.3 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (2.13.2)
# Requirement already satisfied: google-cloud-bigquery<4,>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (3.3.6)
# Requirement already satisfied: google-cloud-recommendations-ai<0.8.0,>=0.1.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (0.7.1)
# Requirement already satisfied: google-cloud-datastore<2,>=1.8.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (1.15.5)
# Requirement already satisfied: google-cloud-pubsublite<2,>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (1.6.0)
# Requirement already satisfied: google-auth-httplib2<0.2.0,>=0.1.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (0.1.0)
# Requirement already satisfied: google-cloud-pubsub<3,>=2.1.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (2.13.11)
# Requirement already satisfied: google-cloud-spanner<4,>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (3.26.0)
# Requirement already satisfied: oauth2client>=1.4.12 in /usr/local/lib/python3.8/dist-packages (from google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (4.1.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (4.9)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from google-cloud-bigquery<4,>=1.6.0->apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (2.4.0)
# Requirement already satisfied: packaging<22.0.0dev,>=14.3 in /usr/local/lib/python3.8/dist-packages (from google-cloud-bigquery<4,>=1.6.0->apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (21.3)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.8/dist-packages (from google-cloud-bigquery<4,>=1.6.0->apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (2.8.2)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.8/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery<4,>=1.6.0->apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (1.57.0)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in /usr/local/lib/python3.8/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-bigquery<4,>=1.6.0->apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (1.48.2)
# Requirement already satisfied: grpc-google-iam-v1<0.13dev,>=0.12.3 in /usr/local/lib/python3.8/dist-packages (from google-cloud-bigtable<2,>=0.31.1->apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (0.12.4)
# Requirement already satisfied: overrides<7.0.0,>=6.0.1 in /usr/local/lib/python3.8/dist-packages (from google-cloud-pubsublite<2,>=1.2.0->apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (6.5.0)
# Requirement already satisfied: sqlparse>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from google-cloud-spanner<4,>=3.0.0->apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (0.4.3)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.8/dist-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery<4,>=1.6.0->apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (1.5.0)
# Requirement already satisfied: docopt in /usr/local/lib/python3.8/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (0.6.2)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.8/dist-packages (from oauth2client>=1.4.12->google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (0.4.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging<22.0.0dev,>=14.3->google-cloud-bigquery<4,>=1.6.0->apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (1.24.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (2.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]<3,>=2.40->tensorflow-data-validation) (2022.12.7)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.11->tensorflow-data-validation) (3.1.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.11->tensorflow-data-validation) (0.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.11->tensorflow-data-validation) (0.28.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.11->tensorflow-data-validation) (1.14.1)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.11->tensorflow-data-validation) (22.12.6)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.11->tensorflow-data-validation) (2.11.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.11->tensorflow-data-validation) (2.11.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.11->tensorflow-data-validation) (3.3.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.11->tensorflow-data-validation) (14.0.6)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.11->tensorflow-data-validation) (2.1.1)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.11->tensorflow-data-validation) (2.11.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.11->tensorflow-data-validation) (1.6.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.11->tensorflow-data-validation) (0.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.11->tensorflow-data-validation) (57.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow<3,>=2.11->tensorflow-data-validation) (0.38.4)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<3,>=2.11->tensorflow-data-validation) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<3,>=2.11->tensorflow-data-validation) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<3,>=2.11->tensorflow-data-validation) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<3,>=2.11->tensorflow-data-validation) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<3,>=2.11->tensorflow-data-validation) (3.4.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow<3,>=2.11->tensorflow-data-validation) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow<3,>=2.11->tensorflow-data-validation) (5.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow<3,>=2.11->tensorflow-data-validation) (3.11.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow<3,>=2.11->tensorflow-data-validation) (3.2.2)
# Requirement already satisfied: google-api-python-client<2,>=1.7.11 in /usr/local/lib/python3.8/dist-packages (from tfx-bsl<1.13,>=1.12.0->tensorflow-data-validation) (1.12.11)
# Requirement already satisfied: tensorflow-serving-api!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,<3,>=1.15 in /usr/local/lib/python3.8/dist-packages (from tfx-bsl<1.13,>=1.12.0->tensorflow-data-validation) (2.11.0)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from google-api-python-client<2,>=1.7.11->tfx-bsl<1.13,>=1.12.0->tensorflow-data-validation) (3.0.1)

# %% [markdown]
# ## Stage 2: Import project dependencies

# %%
import pandas as pd
import tensorflow as tf
import tensorflow_data_validation as tfdv

# %% [markdown]
# ## Stage 3: Simple dataset analysis

# %%
dataset = pd.read_csv('pollution_small.csv')
dataset.shape
# Out:
# (2188, 5)

# %%
training_data = dataset[:1600]
training_data.describe()
# Out:
#               pm10          no2          so2         soot
# count  1600.000000  1600.000000  1600.000000  1600.000000
# mean     49.656494    30.980519    16.229981    21.551956
# std      35.211906    12.400788    10.621896    12.127354
# min       6.380000     9.740000     4.010000     6.000000
# 25%      28.345000    22.567500     9.777500    14.400000
# 50%      38.835000    28.715000    13.275000    18.630000
# 75%      58.050000    36.370000    19.282500    24.072500
# max     277.250000   138.010000   123.130000   107.650000

# %%
test_set = dataset[1600:]
test_set.describe()
# Out:
#              pm10         no2         so2        soot
# count  588.000000  588.000000  588.000000  588.000000
# mean    44.648248   37.296922   13.605170   18.441310
# std     28.992087   10.940050    5.098944    6.596459
# min     11.900000   15.070000    4.990000    8.000000
# 25%     28.337500   29.217500   10.122500   14.410000
# 50%     35.555000   35.815000   12.345000   17.090000
# 75%     50.812500   43.872500   15.855000   20.962500
# max    273.770000  106.030000   38.030000   87.210000

# %% [markdown]
# ## Stage 3: Data analysis and validation with TFDV

# %% [markdown]
# ### Generate training data statistics

# %%
train_stats = tfdv.generate_statistics_from_dataframe(dataframe=dataset)

# %% [markdown]
# ### Infering the schema

# %%
schema = tfdv.infer_schema(statistics=train_stats)

# %%
tfdv.display_schema(schema)
# Out:
#                Type  Presence Valency Domain
# Feature name
# 'Date'        BYTES  required              -
# 'pm10'        FLOAT  required              -
# 'no2'         FLOAT  required              -
# 'so2'         FLOAT  required              -
# 'soot'        FLOAT  required              -

# %% [markdown]
# ### Calculate test set statistics

# %%
test_stats = tfdv.generate_statistics_from_dataframe(dataframe=test_set)

# %% [markdown]
# ## Stage 4: Compare test statistics with the Schema

# %% [markdown]
# ### Checking for anomalies in new data

# %%
anomalies = tfdv.validate_statistics(statistics=test_stats, schema= schema)

# %% [markdown]
# ### Displaying all detected anomalies
#
# - Integer larger than 10
# - STRING type when expected INT type
# - FLOAT type when expected INT type
# - Integer smaller than 0

# %%
tfdv.display_anomalies(anomalies)
# Out:
# <h4 style="color:green;">No anomalies found.</h4>

# %% [markdown]
# ### New data WITH anomalies

# %%
test_set_copy = test_set.copy()

# %%
test_set_copy.drop('soot', axis=1, inplace=True)

# %% [markdown]
# ### Statistics based on data with anomalies

# %%
test_set_copy_stats = tfdv.generate_statistics_from_dataframe(dataframe=test_set_copy)

# %%
anomalies_new = tfdv.validate_statistics(statistics=test_set_copy_stats, schema = schema)

# %%
tfdv.display_anomalies(anomalies_new)
# Out:
#              Anomaly short description      Anomaly long description
# Feature name
# 'soot'                  Column dropped  Column is completely missing

# %% [markdown]
# ## Stage 5: Prepare the schema for Serving

# %%
schema.default_environment.append('TRAINING')
schema.default_environment.append('SERVING')

# %% [markdown]
# ### Removing a target column from the Serving shema

# %%
tfdv.get_feature(schema, 'soot').not_in_environment.append('serving')

# %% [markdown]
# ### Checking for anomalies between the SERVING environment and new test set

# %%
serving_env_anomalies = tfdv.validate_statistics(statistics=test_set_copy_stats, schema=schema, environment='SERVING')

# %%
tfdv.display_anomalies(serving_env_anomalies)
# Out:
#              Anomaly short description      Anomaly long description
# Feature name
# 'soot'                  Column dropped  Column is completely missing

# %% [markdown]
# ## Stage 6: Freezing the schema

# %%
tfdv.write_schema_text(schema=schema, output_path='pollution_schema.pbtxt')
